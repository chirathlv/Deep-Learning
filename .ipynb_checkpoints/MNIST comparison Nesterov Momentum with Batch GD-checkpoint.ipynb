# %%
# import packages
import sys
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# load the dataset
df = pd.read_csv("../../DataSet/mnist_train.csv")

# %%
# input and output features
X = df.iloc[:,1:].to_numpy() / 255.0 # Normalizing between 0 to 1
Y = df.iloc[:,0].to_numpy()

# %%
# split into train and test data
Xtrain, Xtest, Ytrain, Ytest = X[:-1000], X[-1000:], Y[:-1000], Y[-1000:]

# %%
# Shuffle the training data
Xtrain, Ytrain = shuffle(Xtrain, Ytrain)

# %%
# Show PIC func
def showPIC(x,y):
    plt.figure(figsize=(2,2))
    plt.title("Digit: "+str(y))
    plt.imshow(x.reshape(28,28))
    plt.show()

# %%
# Testing a PIC
pic_id = 1
showPIC(Xtrain[pic_id], Ytrain[pic_id])
# Out:
# <img src="data:image/png;base64,..." width="200">

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
def tanh(z):
    return (np.exp(z) - np.exp(-z)) / (np.exp(z) + np.exp(-z))

# %%
def relu(z):
    return z*(z>0)

# %%
def softmax(z):
    return np.exp(z) / np.exp(z).sum(axis=1, keepdims=True)

# %%
def oneHotEncode(y):
    T = np.zeros((y.shape[0], np.unique(y).shape[0]))
    
    for i,val in enumerate(y):
        T[i,val] = 1
        
    return T

# %%
def nonlinearDr(z,activation):
    if activation=="sigmoid":
        return z*(1-z)
    if activation=="tanh":
        return (1-z**2)
    if activation=="relu":
        return (z>0)

# %%
def cost(t,y):
    return -np.sum(t*np.log(y))

# %%
def forward(X,T,hidden,activation,W,B,A,Vw,Vb,i,seed):
    D = X.shape[1]
    K = T.shape[1]
    L = len(hidden)
    
    for l in range(L+1):
        if l==0:
            if i==0:
                W[l] = np.random.randn(D,hidden[l])
                B[l] = np.random.randn(hidden[l])
                Vw[l] = 0
                Vb[l] = 0
            A[l] = activation(np.dot(X,W[l])+B[l])
            
        elif l==L:
            if i==0:
                W[l] = np.random.randn(hidden[l-1],K)
                B[l] = np.random.randn(K)
                Vw[l] = 0
                Vb[l] = 0
            A[l] = softmax(np.dot(A[l-1],W[l])+B[l])
            Y = A[l]
            
        else:
            if i==0:
                W[l] = np.random.randn(hidden[l-1],hidden[l])
                B[l] = np.random.randn(hidden[l])
                Vw[l] = 0
                Vb[l] = 0
            A[l] = activation(np.dot(A[l-1],W[l])+B[l])
    
    return W,B,A,Vw,Vb,Y

# %%
def backprop(X,T,Y,hidden,activation,lr,momentum,Nesterov,W,B,A,Vw,Vb):
    L = len(hidden)
    Err,Grad = {},{}
    
    for l in range(L,-1,-1):
        if l==L:
            Err[l] = T-Y
            Grad[l] = Err[l]
            
        else:
            Err[l] = np.dot(Grad[l+1],W[l+1].T)
            Grad[l] = Err[l]*nonlinearDr(A[l],activation.__name__)
            
    for l in range(L+1):
        if Nesterov:
            if l==0:
                Vw[l] = Vw[l] * momentum + lr * np.dot(X.T,Grad[l])
                Vb[l] = Vb[l] * momentum + lr * Grad[l].sum(axis=0)
                W[l] += Vw[l] * momentum + lr * np.dot(X.T,Grad[l])
                B[l] += Vb[l] * momentum + lr * Grad[l].sum(axis=0)
            else:
                Vw[l] = Vw[l] * momentum + lr * np.dot(A[l-1].T, Grad[l])
                Vb[l] = Vb[l] * momentum + lr * Grad[l].sum(axis=0)
                W[l] += Vw[l] * momentum + lr * np.dot(A[l-1].T, Grad[l])
                B[l] += Vb[l] * momentum + lr * Grad[l].sum(axis=0)
        else:
            if l==0:
                Vw[l] = Vw[l] * momentum + lr * np.dot(X.T,Grad[l])
                Vb[l] = Vb[l] * momentum + lr * Grad[l].sum(axis=0)
                W[l] += Vw[l]
                B[l] += Vb[l]
            else:
                Vw[l] = Vw[l] * momentum + lr * np.dot(A[l-1].T, Grad[l])
                Vb[l] = Vb[l] * momentum + lr * Grad[l].sum(axis=0)
                W[l] += Vw[l]
                B[l] += Vb[l]
            
    return W,B,Vw,Vb

# %%
def train(X,Ytrain,Xtest,Ytest,hidden,activation,iterations,lr,momentum,Nesterov,batch_size,seed):
    N = X.shape[0]
    n_batches = N // batch_size
    
    T = oneHotEncode(Ytrain)
    Ttest = oneHotEncode(Ytest)
    W,B,A,Vw,Vb = {},{},{},{},{}
    Ctrain, Ctest = [],[]
    
    for i in range(iterations):
        for j in range(n_batches):
            start = batch_size*j
            end = batch_size*(j+1)
            
            W,B,A,Vw,Vb,Y = forward(X[start:end],T[start:end],hidden,activation,W,B,A,Vw,Vb,i,seed)
            W,B,Vw,Vb = backprop(X[start:end],T[start:end],Y,hidden,activation,lr,momentum,Nesterov,W,B,A,Vw,Vb)
            _,_,_,_,_,Y_test = forward(Xtest,Ttest,hidden,activation,W,B,A,Vw,Vb,i,seed)

            trCost = cost(T[start:end],Y)
            teCost = cost(Ttest,Y_test)

            Ctrain.append(trCost)
            Ctest.append(teCost)

            sys.stdout.write("\rIterations: {} | Batch: {} | Training Cost: {} | Test Cost: {}".format(
                i+1, j+1, trCost, teCost))
        
    return Ctrain, Ctest, W, B, Vw, Vb, Y, Y_test

# %%
# Full Gradient Descent - No Momentum
hidden = [100]
activation = sigmoid
iterations = 100
lr = 0.00001
momentum = 0
Nesterov = False
batch_size = Xtrain.shape[0] # All the samples
seed = 1

Ctrain_full, Ctest_full, W, B, Vw, Vb, Y, Y_test = train(Xtrain,Ytrain,Xtest,Ytest,hidden,activation,iterations,lr,
                                                         momentum,
                                                         Nesterov,
                                                         batch_size,
                                                         seed)
# Out:
# Iterations: 100 | Batch: 1 | Training Cost: 55858.407158327 | Test Cost: 809.4569865889831497

# %%
# Mini Batch Gradient Descent - No Momentum
hidden = [100]
activation = sigmoid
iterations = 100
lr = 0.00001
momentum = 0
Nesterov = False
batch_size = 10000 # Batch Sample size
seed = 1

Ctrain_batch, Ctest_batch, W, B, Vw, Vb, Y, Y_test = train(Xtrain,Ytrain,Xtest,Ytest,hidden,activation,iterations,lr,
                                                         momentum,
                                                         Nesterov,
                                                         batch_size,
                                                         seed)
# Out:
# Iterations: 100 | Batch: 5 | Training Cost: 10361.862963761341 | Test Cost: 788.3414139998958

# %%
# Mini Batch Gradient Descent with Momentum
hidden = [100]
activation = sigmoid
iterations = 100
lr = 0.00001
momentum = 0.95
Nesterov = False
batch_size = 10000 # Batch Sample size
seed = 1

Ctrain_batch_m, Ctest_batch_m, W, B, Vw, Vb, Y, Y_test = train(Xtrain,Ytrain,Xtest,Ytest,hidden,activation,iterations,lr,
                                                         momentum,
                                                         Nesterov,
                                                         batch_size,
                                                         seed)
# Out:
# Iterations: 100 | Batch: 5 | Training Cost: 2832.2777183230296 | Test Cost: 280.69428069796524

# %%
# Mini Batch Gradient Descent with Nesterov Momentum
hidden = [100]
activation = sigmoid
iterations = 100
lr = 0.00001
momentum = 0.95
Nesterov = True # Turned this ON
batch_size = 10000 # Batch Sample size
seed = 1

Ctrain_batch_nm, Ctest_batch_nm, W, B, Vw, Vb, Y, Y_test = train(Xtrain,Ytrain,Xtest,Ytest,hidden,activation,iterations,lr,
                                                         momentum,
                                                         Nesterov,
                                                         batch_size,
                                                         seed)
# Out:
# Iterations: 100 | Batch: 5 | Training Cost: 2889.831021751705 | Test Cost: 273.828956373959955

# %%
plt.figure(figsize=(6,6))
plt.plot(Ctest_full, label="Full GD")
plt.plot(Ctest_batch, label="Batch GD")
plt.plot(Ctest_batch_m, label="Batch GD - Momentum")
plt.plot(Ctest_batch_nm, label="Batch GD - Nesterov Momentum")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
